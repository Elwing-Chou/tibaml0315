# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibaml0315/blob/main/%E8%A7%A3%E9%87%8BCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import math

p1 = 0.7
p2 = 1 - p1

xs = []
ys = []
intervals = 0.001

minp, minv = None, float("inf")
for i in range(998):
    q1 = (i + 1) * intervals
    q2 = 1 - q1
    xs.append(q1)
    ans = p1 * math.log(1/q1, 2) + p2 * math.log(1/q2, 2)
    ys.append(ans)
    if ans < minv:
        minp, minv = q1, ans
print(minp, minv)
plt.plot(xs, ys)
# Out:
# 0.7000000000000001 0.8812908992306925

# %%
p1 = 0.7
p2 = 1 - p1

xs = []
ys = []
intervals = 0.001

minp, minv = None, float("inf")
for i in range(998):
    q1 = (i + 1) * intervals
    q2 = 1 - q1
    xs.append(q1)
    ans = p1 * (1 - q1) + p2 * (1 - q2)
    ys.append(ans)
    if ans < minv:
        minp, minv = q1, ans
print(minp, minv)
plt.plot(xs, ys)
# Out:
# 0.998 0.30080000000000007
